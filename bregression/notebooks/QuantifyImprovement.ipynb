# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sample='ttbar'
path='/scratch/snx3000/nchernya/bregression/plots/quantiles/2018-03-12/2018-03-01_job23_rawJetsJECtarget/%s/'%sample

# %%
whats=['p_T','eta','rho']
which = 0

# %%
where=''
files = 'data_IQR_compare_%s_%s%s.csv'%(whats[which],sample,where)
df = pd.read_csv(path+files)

# %%
to_compare=['p_T','delta_Hbb_JEC_rel','delta_ETH_JEC_rel','delta_ETH_JEC_rel','delta_Pisa_JEC_rel','delta_ETH_Pisa_JEC_rel']
#df[to_compare].round(3)

# %%
ax = df.plot.scatter(x='%s'%whats[which],y='delta_Hbb_JEC_rel',color='r',s=61,label='Set 0 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_JEC_rel',color='g',s=61,ax=ax,label='Set 1 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_Pisa_JEC_rel',color='b',s=61,ax=ax,label='Set 2 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_JEC_rel',color='c',s=61,ax=ax,label='Set 3 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_JEC_rel',color='black',s=61,ax=ax,label='Set 3 w/o jec vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_JEC_rel',color='magenta',marker='>',s=61,ax=ax,label='Set 3 w/o jec,ptd vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_noislepton_JEC_rel',color='orange',marker='>',s=61,ax=ax,label='Set 3 w/o jec,ptd,isLepton vs JEC ')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_noislepton_nomass_JEC_rel',color='lime',marker='>',s=61,ax=ax,label='Set 3 w/o jec,ptd,isLepton,mass vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nochEmEf_JEC_rel',color='gold',marker='>',s=61,ax=ax,label='Set 3 w/o chEmEF vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_mass_JEC_rel',color='brown',marker='>',s=61,ax=ax,label='Set 1 plus mass vs JEC')


ax.set_ylabel('$\\frac{\Delta \sigma/\mu}{\sigma/\mu_{JEC}}$ ') 
axes = plt.gca()
axes.set_ylim(-0.16,0.10)
savename='delta_sigma_mu_jec_norol_%s_%s%s'%(whats[which],sample,where)
plt.savefig(path+savename+'.pdf')
plt.savefig(path+savename+'.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-deff7e666017> in <module>()
# ----> 1 ax = df.plot.scatter(x='%s'%whats[which],y='delta_Hbb_JEC_rel',color='r',s=61,label='Set 0 vs JEC')
#       2 df.plot.scatter(x='%s'%whats[which],y='delta_ETH_JEC_rel',color='g',s=61,ax=ax,label='Set 1 vs JEC')
#       3 df.plot.scatter(x='%s'%whats[which],y='delta_Pisa_JEC_rel',color='b',s=61,ax=ax,label='Set 2 vs JEC')
#       4 df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_JEC_rel',color='c',s=61,ax=ax,label='Set 3 vs JEC')
#       5 df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_JEC_rel',color='black',s=61,ax=ax,label='Set 3 w/o jec vs JEC')
#
# NameError: name 'df' is not defined

# %%
path2='/scratch/snx3000/nchernya/bregression/plots/quantiles/2018-03-13/forPisaTalk/%s/'%sample
ax = df.plot.scatter(x='%s'%whats[which],y='delta_Hbb_JEC_rel',color='r',s=61,label='Set 0 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_JEC_rel',color='g',s=61,ax=ax,label='Set 1 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_Pisa_JEC_rel',color='b',s=61,ax=ax,label='Set 2 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_JEC_rel',color='c',s=61,ax=ax,label='Set 3 vs JEC')
ax.set_ylabel('$\\frac{\Delta \sigma/\mu}{\sigma/\mu_{JEC}}$ ') 
axes = plt.gca()
axes.set_ylim(-0.16,0.10)
plt.tight_layout()

savename='delta_sigma_mu_jec_norol_%s_%s%s'%(whats[which],sample,where)
plt.savefig(path2+savename+'.pdf')
plt.savefig(path2+savename+'.png')
plt.show()

ax = df.plot.scatter(x='%s'%whats[which],y='delta_Hbb_JEC_rel',color='r',s=61,label='Set 0 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_JEC_rel',color='g',s=61,ax=ax,label='Set 1 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_Pisa_JEC_rel',color='b',s=61,ax=ax,label='Set 2 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_JEC_rel',color='c',s=61,ax=ax,label='Set 3 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_JEC_rel',color='black',s=61,ax=ax,label='Set 3 w/o jec vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_JEC_rel',color='magenta',marker='>',s=61,ax=ax,label='Set 3 w/o jec,ptd vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_noislepton_JEC_rel',color='orange',marker='>',s=61,ax=ax,label='Set 3 w/o jec,ptd,isLepton vs JEC ')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_noislepton_nomass_JEC_rel',color='lime',marker='>',s=61,ax=ax,label='Set 3 w/o jec,ptd,isLepton,mass vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nochEmEf_JEC_rel',color='violet',marker='>',s=61,ax=ax,label='Set 3 w/o chEmEF vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_ETH_mass_JEC_rel',color='brown',marker='>',s=61,ax=ax,label='Set 1 plus mass vs JEC')


ax.set_ylabel('$\\frac{\Delta \sigma/\mu}{\sigma/\mu_{JEC}}$ ') 
axes = plt.gca()
axes.set_ylim(-0.16,0.10)
plt.tight_layout()
savename='delta_sigma_mu_jec_norol_all_%s_%s%s'%(whats[which],sample,where)
plt.savefig(path2+savename+'.pdf')
plt.savefig(path2+savename+'.png')
plt.show()

# %%
ax = df.plot.scatter(x='%s'%whats[which],y='sigma_Hbb',color='r',s=61,label='HIG-16-044 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='sigma_ETH',color='g',s=61,ax=ax,label='Set 1 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='sigma_Pisa',color='b',s=61,ax=ax,label='Set 2 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='sigma_ETH_Pisa',color='c',s=61,ax=ax,label='Set 3 vs JEC')
ax.set_ylabel('$\sigma$ ')
axes = plt.gca()
axes.set_ylim(0.,0.25)
savename='sigma_%s_%s%s'%(whats[which],sample,where)
plt.savefig(path+savename+'.pdf')
plt.savefig(path+savename+'.png')
plt.show()

# %%
ax = df.plot.scatter(x='%s'%whats[which],y='delta_sigma_Hbb_JEC_rel',color='r',s=61,label='Set 0 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_sigma_ETH_JEC_rel',color='g',s=61,ax=ax,label='Set 1 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_sigma_Pisa_JEC_rel',color='b',s=61,ax=ax,label='Set 2 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_sigma_ETH_Pisa_JEC_rel',color='c',s=61,ax=ax,label='Set 3 vs JEC')
#df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_JEC_rel',color='black',s=61,ax=ax,label='Set 3 w/o jec vs JEC')
#df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_JEC_rel',color='magenta',marker='>',s=61,ax=ax,label='Set 3 w/o jec vs JEC,ptd')
ax.set_ylabel('$\\frac{\Delta \sigma}{\sigma_{JEC}}$ ') 
axes = plt.gca()
axes.set_ylim(-0.4,0.1)
savename='delta_sigma_%s_%s%s'%(whats[which],sample,where)
plt.savefig(path+savename+'.pdf')
plt.savefig(path+savename+'.png')
plt.show()

# %%
ax = df.plot.scatter(x='%s'%whats[which],y='delta_mu_Hbb_JEC_rel',color='r',s=61,label='Set 0 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_mu_ETH_JEC_rel',color='g',s=61,ax=ax,label='Set 1 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_mu_Pisa_JEC_rel',color='b',s=61,ax=ax,label='Set 2 vs JEC')
df.plot.scatter(x='%s'%whats[which],y='delta_mu_ETH_Pisa_JEC_rel',color='c',s=61,ax=ax,label='Set 3 vs JEC')
#df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_JEC_rel',color='black',s=61,ax=ax,label='Set 3 w/o jec vs JEC')
#df.plot.scatter(x='%s'%whats[which],y='delta_ETH_Pisa_nojec_noptd_JEC_rel',color='magenta',marker='>',s=61,ax=ax,label='Set 3 w/o jec vs JEC,ptd')
ax.set_ylabel('$\\frac{\Delta \mu}{\mu_{JEC}}$ ') 
axes = plt.gca()
axes.set_ylim(-0.4,0.1)
savename='delta_mu_%s_%s%s'%(whats[which],sample,where)
plt.savefig(path+savename+'.pdf')
plt.savefig(path+savename+'.png')
plt.show()

# %%
testfile = '/scratch/snx3000/nchernya/bregression/output_root/applied_res_2018-03-09_ttbar_full_RegressionPerJet_heppy_energyRings_testing_morevar.hd5'

# %%
df_test = pd.read_hdf(testfile,columns=None)
#df_test[['isEle','isMu','isOther']]
print(df_test.query('isEle==1').shape)
print(df_test.query('isMu==1').shape)
print(df_test.query('isOther==1').shape)
print(df_test.query('isOther==0').shape)
print(df_test.shape)
296524/1302762
# Out:
# (296524, 99)
# (206975, 99)
# (1302762, 99)
# (503499, 99)
# (1806261, 99)
# 0.22761179708956816

# %%
#df_test[['Jet_pt_reg_NN_2018-03-02_job23_rawJetsJECtarget_us_plus_pisa_nojec_noptd','Jet_pt_reg_NN_2018-03-02_job23_rawJetsJECtarget_us_plus_pisa_nojec']]
df_test2 = df_test.query("Jet_pt>500")

# %%
hist = plt.hist2d(df_test2['Jet_pt'].ravel(), df_test2['Jet_chEmEF'].ravel(), bins=[100,np.linspace(0.,0.04,10)],cmap='viridis')

# %%
plt.hist(df_test['Jet_chEmEF'],bins=200,log=True)
#df_test.is_null()
# Out:
# (array([  1.48505200e+06,   2.88000000e+02,   8.80000000e+02,
#           1.83900000e+03,   2.92200000e+03,   3.90000000e+03,
#           4.67300000e+03,   5.25700000e+03,   5.66400000e+03,
#           5.76400000e+03,   5.79800000e+03,   5.96900000e+03,
#           5.80500000e+03,   5.82700000e+03,   5.64500000e+03,
#           5.43900000e+03,   5.37100000e+03,   5.38500000e+03,
#           5.24600000e+03,   5.09500000e+03,   5.05100000e+03,
#           4.91100000e+03,   4.76700000e+03,   4.49300000e+03,
#           4.53200000e+03,   4.40800000e+03,   4.32100000e+03,
#           4.14800000e+03,   4.19900000e+03,   4.09500000e+03,
#           4.03900000e+03,   3.98000000e+03,   3.90200000e+03,
#           3.68400000e+03,   3.57300000e+03,   3.69700000e+03,
#           3.66700000e+03,   3.57100000e+03,   3.46400000e+03,
#           3.43900000e+03,   3.30700000e+03,   3.33600000e+03,
#           3.21400000e+03,   3.15300000e+03,   3.17300000e+03,
#           3.15900000e+03,   3.08000000e+03,   3.10900000e+03,
#           2.87400000e+03,   2.95800000e+03,   2.85100000e+03,
#           2.76300000e+03,   2.88600000e+03,   2.79700000e+03,
#           2.68700000e+03,   2.68600000e+03,   2.63200000e+03,
#           2.67000000e+03,   2.61400000e+03,   2.52300000e+03,
#           2.60800000e+03,   2.44200000e+03,   2.45100000e+03,
#           2.42900000e+03,   2.42600000e+03,   2.30400000e+03,
#           2.22500000e+03,   2.21800000e+03,   2.22300000e+03,
#           2.18500000e+03,   2.14700000e+03,   2.04100000e+03,
#           1.98000000e+03,   1.95600000e+03,   1.93400000e+03,
#           1.88800000e+03,   1.81200000e+03,   1.84200000e+03,
#           1.83200000e+03,   1.78300000e+03,   1.74300000e+03,
#           1.69300000e+03,   1.69400000e+03,   1.61700000e+03,
#           1.60400000e+03,   1.53400000e+03,   1.54500000e+03,
#           1.41800000e+03,   1.37500000e+03,   1.38000000e+03,
#           1.37900000e+03,   1.39500000e+03,   1.28700000e+03,
#           1.30300000e+03,   1.23500000e+03,   1.23900000e+03,
#           1.15800000e+03,   1.16200000e+03,   1.18300000e+03,
#           1.07300000e+03,   1.06700000e+03,   1.04500000e+03,
#           1.01200000e+03,   9.74000000e+02,   9.31000000e+02,
#           9.46000000e+02,   8.74000000e+02,   8.32000000e+02,
#           7.87000000e+02,   7.74000000e+02,   7.83000000e+02,
#           7.52000000e+02,   7.01000000e+02,   7.33000000e+02,
#           6.57000000e+02,   6.18000000e+02,   5.99000000e+02,
#           5.65000000e+02,   5.44000000e+02,   5.54000000e+02,
#           5.00000000e+02,   4.74000000e+02,   4.54000000e+02,
#           4.15000000e+02,   4.21000000e+02,   3.79000000e+02,
#           3.84000000e+02,   3.14000000e+02,   3.42000000e+02,
#           3.31000000e+02,   2.89000000e+02,   2.51000000e+02,
#           2.46000000e+02,   1.98000000e+02,   2.21000000e+02,
#           2.03000000e+02,   1.72000000e+02,   1.69000000e+02,
#           1.44000000e+02,   1.22000000e+02,   1.12000000e+02,
#           1.08000000e+02,   7.30000000e+01,   8.80000000e+01,
#           8.50000000e+01,   9.10000000e+01,   6.50000000e+01,
#           5.80000000e+01,   7.20000000e+01,   5.20000000e+01,
#           4.20000000e+01,   4.40000000e+01,   3.10000000e+01,
#           4.80000000e+01,   3.60000000e+01,   3.40000000e+01,
#           3.10000000e+01,   3.50000000e+01,   3.10000000e+01,
#           2.10000000e+01,   1.50000000e+01,   2.30000000e+01,
#           2.40000000e+01,   2.30000000e+01,   1.70000000e+01,
#           2.10000000e+01,   1.30000000e+01,   2.00000000e+01,
#           1.90000000e+01,   1.40000000e+01,   1.10000000e+01,
#           1.60000000e+01,   1.40000000e+01,   1.00000000e+01,
#           9.00000000e+00,   1.20000000e+01,   8.00000000e+00,
#           9.00000000e+00,   3.00000000e+00,   5.00000000e+00,
#           8.00000000e+00,   8.00000000e+00,   5.00000000e+00,
#           3.00000000e+00,   4.00000000e+00,   2.00000000e+00,
#           6.00000000e+00,   3.00000000e+00,   4.00000000e+00,
#           5.00000000e+00,   5.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   2.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   2.00000000e+00,   2.00000000e+00,
#           2.00000000e+00,   2.00000000e+00]),
#  array([ 0.        ,  0.00479179,  0.00958358,  0.01437536,  0.01916715,
#          0.02395894,  0.02875073,  0.03354251,  0.0383343 ,  0.04312609,
#          0.04791788,  0.05270966,  0.05750145,  0.06229324,  0.06708503,
#          0.07187681,  0.0766686 ,  0.08146039,  0.08625218,  0.09104396,
#          0.09583575,  0.10062754,  0.10541933,  0.11021111,  0.1150029 ,
#          0.11979469,  0.12458648,  0.12937826,  0.13417005,  0.13896184,
#          0.14375363,  0.14854541,  0.1533372 ,  0.15812899,  0.16292078,
#          0.16771256,  0.17250435,  0.17729614,  0.18208793,  0.18687972,
#          0.1916715 ,  0.19646329,  0.20125508,  0.20604687,  0.21083865,
#          0.21563044,  0.22042223,  0.22521402,  0.2300058 ,  0.23479759,
#          0.23958938,  0.24438117,  0.24917295,  0.25396474,  0.25875653,
#          0.26354832,  0.2683401 ,  0.27313189,  0.27792368,  0.28271547,
#          0.28750725,  0.29229904,  0.29709083,  0.30188262,  0.3066744 ,
#          0.31146619,  0.31625798,  0.32104977,  0.32584155,  0.33063334,
#          0.33542513,  0.34021692,  0.3450087 ,  0.34980049,  0.35459228,
#          0.35938407,  0.36417585,  0.36896764,  0.37375943,  0.37855122,
#          0.38334301,  0.38813479,  0.39292658,  0.39771837,  0.40251016,
#          0.40730194,  0.41209373,  0.41688552,  0.42167731,  0.42646909,
#          0.43126088,  0.43605267,  0.44084446,  0.44563624,  0.45042803,
#          0.45521982,  0.46001161,  0.46480339,  0.46959518,  0.47438697,
#          0.47917876,  0.48397054,  0.48876233,  0.49355412,  0.49834591,
#          0.50313769,  0.50792948,  0.51272127,  0.51751306,  0.52230484,
#          0.52709663,  0.53188842,  0.53668021,  0.54147199,  0.54626378,
#          0.55105557,  0.55584736,  0.56063915,  0.56543093,  0.57022272,
#          0.57501451,  0.5798063 ,  0.58459808,  0.58938987,  0.59418166,
#          0.59897345,  0.60376523,  0.60855702,  0.61334881,  0.6181406 ,
#          0.62293238,  0.62772417,  0.63251596,  0.63730775,  0.64209953,
#          0.64689132,  0.65168311,  0.6564749 ,  0.66126668,  0.66605847,
#          0.67085026,  0.67564205,  0.68043383,  0.68522562,  0.69001741,
#          0.6948092 ,  0.69960098,  0.70439277,  0.70918456,  0.71397635,
#          0.71876813,  0.72355992,  0.72835171,  0.7331435 ,  0.73793528,
#          0.74272707,  0.74751886,  0.75231065,  0.75710244,  0.76189422,
#          0.76668601,  0.7714778 ,  0.77626959,  0.78106137,  0.78585316,
#          0.79064495,  0.79543674,  0.80022852,  0.80502031,  0.8098121 ,
#          0.81460389,  0.81939567,  0.82418746,  0.82897925,  0.83377104,
#          0.83856282,  0.84335461,  0.8481464 ,  0.85293819,  0.85772997,
#          0.86252176,  0.86731355,  0.87210534,  0.87689712,  0.88168891,
#          0.8864807 ,  0.89127249,  0.89606427,  0.90085606,  0.90564785,
#          0.91043964,  0.91523142,  0.92002321,  0.924815  ,  0.92960679,
#          0.93439858,  0.93919036,  0.94398215,  0.94877394,  0.95356573,
#          0.95835751]),
#  <a list of 200 Patch objects>)

# %%
ax2 = plt.hist((df_test['Jet_energyRing_dR0_ch']+df_test['Jet_energyRing_dR1_ch']+df_test['Jet_energyRing_dR2_ch']+df_test['Jet_energyRing_dR3_ch']+df_test['Jet_energyRing_dR4_ch'])/df_test['Jet_rawEnergy'],bins=200,log=True)

# %%
df_test.plot.scatter(x='Jet_pt',y='isOther')

# %%
# Out:
# array([ 0.28201866,  0.2828739 ,  0.32056397, ...,  0.28780982,
#         0.39807147,  0.3858262 ], dtype=float32)

# %%
df_test3 = df_test.query('Jet_pt>300')

# %%
ax2 = plt.hist(df_test['Jet_mcPt']/(df_test['Jet_pt']*df_test['Jet_pt_reg_NN_2018-03-01_job23_rawJetsJECtarget']),bins=200,log=True)

# %%
ax2 = plt.hist(df_test['Jet_pt_reg_NN_2018-03-02_job23_rawJetsJECtarget_us_plus_pisa_nochEmEF'],bins=200,log=True)

# %%
ax2 = plt.hist(df_test['Jet_mcPt']/(df_test['Jet_pt']*df_test['Jet_corr_JEC']),bins=200,log=True)
